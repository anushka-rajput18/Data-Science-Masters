# %%
import pandas as pd

# %% [markdown]
# **Q1. List any five functions of the pandas library with execution.**

# %% [markdown]
# here are five common functions of the pandas library with examples:
# 1. **read_csv()**: Reads a CSV file and returns a DataFrame object.

# %%
df = pd.read_csv("players.csv")

# %% [markdown]
# 2. **head()**: Returns the first n rows of a DataFrame.

# %%
df.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %% [markdown]
# 3. **groupby()**: Groups the DataFrame by a column or columns and applies a function to each group.

# %%
grouped = df.groupby('Age')
grouped.first()
# Out:
#       Rk           Player  Pos   Tm   G  GS    MP   FG  FGA   FG%  ...   FT%  \
# Age                                                                ...
# 19    78    Bruno Caboclo   SF  TOR   8   0    23    4   12  .333  ...  .625
# 20     2     Jordan Adams   SG  MEM  30   0   248   35   86  .407  ...  .609
# 21     3     Steven Adams    C  OKC  70  67  1771  217  399  .544  ...  .502
# 22    32  Harrison Barnes   SF  GSW  82  82  2318  316  656  .482  ...  .720
# 23     7   Furkan Aldemir   PF  PHI  41   9   540   40   78  .513  ...  .481
# 24     1       Quincy Acy   PF  NYK  68  22  1287  152  331  .459  ...  .784
# 25    10      Lavoy Allen    C  IND  63   0  1070  141  299  .472  ...  .702
# 26     6    Alexis Ajinça    C  NOP  68   8   957  181  329  .550  ...  .818
# 27    25    D.J. Augustin   PG  TOT  82  14  1964  258  647  .399  ...  .868
# 28     4      Jeff Adrien   PF  MIN  17   0   215   19   44  .432  ...  .579
# ...

# %% [markdown]
# 3. **len()**: length of the dataframe

# %%
len(df)
# Out:
# 675

# %% [markdown]
# 4. **unique()**: Returns the unique values in a column of a DataFrame.

# %%
unique_values = df['Tm'].unique()
print(unique_values)
# Out:
# ['NYK' 'MEM' 'OKC' 'MIN' 'TOT' 'DEN' 'POR' 'NOP' 'PHI' 'IND' 'DAL' 'CLE'
#  'MIA' 'BRK' 'SAS' 'MIL' 'DET' 'Tm' 'ATL' 'HOU' 'CHI' 'GSW' 'LAC' 'PHO'
#  'BOS' 'WAS' 'UTA' 'SAC' 'CHO' 'LAL' 'TOR' 'ORL']

# %% [markdown]
# 5. **sort_values()**: Sorts the rows of a DataFrame by one or more columns.

# %%
sorted_df = df.sort_values(["Age"], ascending=[True])
print(sorted_df)
# Out:
#       Rk          Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 460  357   Jabari Parker   PF   19  MIL  25  25   738  129   263  ...  .697
# 621  456     Noah Vonleh   PF   19  CHO  25   0   259   30    76  ...  .692
# 641  473  Andrew Wiggins   SF   19  MIN  82  82  2969  497  1137  ...  .760
# 351  273     Zach LaVine   PG   19  MIN  77  40  1902  286   677  ...  .842
# 231  177    Aaron Gordon   PF   19  ORL  47   8   797   93   208  ...  .721
# ..   ...             ...  ...  ...  ...  ..  ..   ...  ...   ...  ...   ...
# 235   Rk          Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   FT%
# 97    Rk          Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   FT%
# 361   Rk          Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   FT%
# 628   Rk          Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   FT%
# 183   Rk          Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   FT%
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %% [markdown]
# **Q.2 Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the DataFrame with a new index that starts from 1 and increments by 2 for each row.**

# %%
def reindex_dataframe(df):
    # Get the number of rows in the DataFrame
    num_rows = df.shape[0]
    
    # Create a new index that starts from 1 and increments by 2
    new_index = pd.Index(range(1, num_rows*2, 2))
    
    # Re-index the DataFrame
    df_reindexed = df.set_index(new_index)
    
    return df_reindexed

# %%
df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})
df_reindexed = reindex_dataframe(df1)
print(df_reindexed)
# Out:
#    A  B  C
# 1  1  4  7
# 3  2  5  8
# 5  3  6  9
